# %%
# imports
import spacy
from spacy.matcher import PhraseMatcher

# load default skills data base
from skillNer.general_params import SKILL_DB
# import skill extractor
from skillNer.skill_extractor_class import SkillExtractor

# init params of skill extractor
nlp = spacy.load("en_core_web_lg")
# # init skill extractor
skill_extractor = SkillExtractor(nlp, SKILL_DB, PhraseMatcher)

# extract skills from job_description
job_description = """
	processed_description
22	summary . • job summary business intelligence analyst position identifies , manages , provides actionable insights related data analytic needs coxhealth data modeling , business analytics , data visualization , enhancement services . supports , influences , challenges business decisions data , well timely insightful analysis . responsible . management business analytic processes strategies : data integration , operational reporting , ad-hoc analysis , dashboards , data mining . determines reporting analytics needs various programs initiatives , creates customized dashboard performance metrics , reports related aspects healthcare . collaborates stakeholders design , create , test , implement analytic tools , databases , extracts , reports , dashboards , etc , support enterprise needs . strong focus customer service , innovation , delivery highest quality work product , position requires strong technical , critical thinking , project management , interpersonal skills . • job requirements education required : bachelors degree computer information systems , business administration degree , related field 8 years experience computer science experience required : minimum 4 years experience performing data analysis clinical financial information . skills strong knowledge sql data extraction tools . experience using industry standard bi , statistical , analytical tools technologies power bi business objects . working knowledge complex database design concepts . ability design , write , maintain , support complex dashboards , queries , extracts , reports utilizing various reporting tools data sources . demonstrates careful attention detail ability work independently . serves resource identification potential clinical financial performance improvement activities identifying communicating opportunities discovered , identified analysis . prepares clear well-organized project-specific documentation reflect analytic methods used , key decision points , caveats , etc . sufficient detail support comprehension replication analysis . consistently performs validation checks ensure accuracy reports data . excellent systematic problem solving skills . licensure , certification , registration n , a. additional information . job benefits perks . • tuition reimbursement $ 1200 per year . • additional educational assistance programs available . • health , dental , vision . • retirement employer match . • 20 % tuition discount classes cox college . • on-site daycare extended hours , holidays weekends . • employee discount coxhealth fitness centers . • pharmacy delivery unit . • on-site employee health services . • opportunity earn referral bonuses $ 5 , 000 per hire certain positions . • 1906 employee store . • cafeteria discount . would like information job benefits perks , please feel free email us @ hr-recruitment @ visit
"""
annotations = skill_extractor.annotate(job_description)

print(annotations)
# Out:
# loading full_matcher ...
# loading abv_matcher ...
# loading full_uni_matcher ...
# loading low_form_matcher ...
# loading token_matcher ...
# ...

# %%
skill_extractor.describe(annotations)
# Out:
#         <head>
#             <link
#                 id="external-css"
#                 rel="stylesheet"
#                 type="text/css"
#                 href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
#                 media="all"
#             />
#         </head>
#
#         <body>
#             <div id="root" class="px-4 leading-10 mb-24">
#                 &nbspprocessed_description 22 summary • job summary&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS120ZX7019J4V8DHBTM_393()'onmouseenter='mouseEnterHandler_KS120ZX7019J4V8DHBTM_393()'>
#             business intelligence
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS120ZX7019J4V8DHBTM_393'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
# ...
